# %%
import requests

base_url = "https://data.gov.sg/api/action/datastore_search"
url = base_url + "?resource_id=d_45c131f9c746f15d91fe84f261abcc4a"

response = requests.get(url)
print(response.json())
# Out:
# {'help': 'https://data.gov.sg/api/3/action/help_show?name=datastore_search', 'success': True, 'result': {'resource_id': 'd_45c131f9c746f15d91fe84f261abcc4a', 'fields': [{'type': 'text', 'id': 'Thousands'}, {'type': 'numeric', 'id': 'Total'}, {'type': 'numeric', 'id': 'Legislators_SeniorOfficialsandManagers'}, {'type': 'numeric', 'id': 'Professionals'}, {'type': 'numeric', 'id': 'AssociateProfessionalsandTechnicians'}, {'type': 'numeric', 'id': 'ClericalSupportWorkers'}, {'type': 'numeric', 'id': 'ServiceandSalesWorkers'}, {'type': 'numeric', 'id': 'CraftsmenandRelatedTradesWorkers'}, {'type': 'numeric', 'id': 'PlantandMachineOperatorsandAssemblers'}, {'type': 'numeric', 'id': 'Cleaners_LabourersandRelatedWorkers'}, {'type': 'numeric', 'id': 'Others1'}, {'type': 'int4', 'id': '_id'}], 'records': [{'_id': 1, 'Thousands': 'Total', 'Total': '2151.9', 'Legislators_SeniorOfficialsandManagers': '346.8', 'Professionals': '394.1', 'AssociateProfessionalsandTechnicians': '429.5', 'ClericalSupp
# ...
