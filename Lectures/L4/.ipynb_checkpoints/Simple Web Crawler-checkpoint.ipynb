# %%
import requests
from bs4 import BeautifulSoup
from bs4.element import Comment
import re
from pandas import DataFrame
import time

# %%
STARTING_URL = "https://sws.comp.nus.edu.sg/"

# %%
urls = []
htmls = []
texts = []
urls.append(STARTING_URL)
page = requests.get(STARTING_URL)

# %%
#get the raw HTML
htmls.append(page.content)
page.content
# Out:
# b'<!DOCTYPE html>\n<html style="font-size: 16px;" lang="en"><head>\n    <meta name="viewport" content="width=device-width, initial-scale=1.0">\n    <meta charset="utf-8">\n    <meta name="keywords" content="\xe2\x80\x8b&nbsp;SUMMER WORSHOP 2024">\n    <meta name="description" content="">\n    <title>Home</title>\n    <link rel="stylesheet" href="nicepage.css" media="screen">\n<link rel="stylesheet" href="Home.css" media="screen">\n    <script class="u-script" type="text/javascript" src="jquery.js" defer=""></script>\n    <script class="u-script" type="text/javascript" src="nicepage.js" defer=""></script>\n    <meta name="generator" content="Nicepage 6.4.0, nicepage.com">\n    <link id="u-theme-google-font" rel="stylesheet" href="https://fonts.googleapis.com/css?family=Roboto:100,100i,300,300i,400,400i,500,500i,700,700i,900,900i|Open+Sans:300,300i,400,400i,500,500i,600,600i,700,700i,800,800i">\n    <link id="u-page-google-font" rel="stylesheet" href="https://fonts.googleapis.com/css?family=Montserrat:100,100i,200,200i,300,300i,400,400i,500,500i,600,600i,700,700i,800,800i,900,900i|Comic+Neue:300,300i,400,400i,700,700i">\n    \n    \n    \n    \n    \n    \n    \n    \n    <script type="application/ld+json">{\n\t\t"@context": "http://schema.org",\n\t\t"@type": "Organization",\n\t\t"name": "Site2",\n\t\t"logo": "images/logo.png"\n}</script>\n    <meta name="theme-color" content="#478ac9">\n    <meta property="og:title" content="Home">\n    <meta property="og:description" content="">\n    <meta property="og:type" content="website">\n  <meta data-intl-tel-input-cdn-path="intlTelInput/"></head>\n  <body data-home-page="Home.html" data-home-page-title="Home" data-path-to-root="./" data-include-products="false" class="u-body u-xl-mode" data-lang="en"><header class=" u-border-no-bottom u-border-no-left u-border-no-right u-border-no-top u-clearfix u-header u-section-row-container" id="sec-1cca" data-animation-name="" data-animation-duration="0" data-animation-delay="0" data-animation-direction="" style=""><div class="u-section-rows" style="">\n        <div class="u-clearfix u-section-row" data-animation-name="" data-animation-duration="0" data-animation-delay="0" data-animation-direction="" id="sec-781a">\n          <div class="u-clearfix u-sheet u-sheet-1">\n            <a href="https://www.comp.nus.edu.sg/" class="u-align-left u-image u-logo u-image-1" data-image-width="644" data-image-height="115" title="NUS School of Computing" target="_blank">\n              <img src="images/logo.png" class="u-logo-image u-logo-image-1">\n            </a>\n          </div>\n          \n          \n          \n          \n          \n        </div>\n        <div class="u-section-row" id="sec-2aa7">\n          <div class="u-clearfix u-sheet u-valign-middle u-sheet-2">\n            <nav class="u-align-center-lg u-align-center-xl u-align-left-md u-align-left-sm u-align-left-xs u-menu u-menu-one-level u-offcanvas u-menu-1">\n              <div class="menu-collapse" style="font-size: 1rem; letter-spacing: 0px;">\n                <a class="u-button-style u-custom-left-right-menu-spacing u-custom-padding-bottom u-custom-top-bottom-menu-spacing u-nav-link u-text-active-palette-1-base u-text-hover-palette-2-base" href="#">\n                  <svg class="u-svg-link" viewBox="0 0 24 24"><use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="#svg-deba"></use></svg>\n                  <svg class="u-svg-content" version="1.1" id="svg-deba" viewBox="0 0 16 16" x="0px" y="0px" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg"><g><rect y="1" width="16" height="2"></rect><rect y="7" width="16" height="2"></rect><rect y="13" width="16" height="2"></rect>\n</g></svg>\n                </a>\n              </div>\n              <div class="u-custom-menu u-nav-container">\n                <ul class="u-nav u-unstyled u-nav-1"><li class="u-nav-item"><a class="u-button-style u-nav-link u-text-active-palette-1-base u-text-hover-palette-2-base" h ...

# %%
#parse the HTML
soup = BeautifulSoup(page.content, 'html.parser')

# %%
#pretty print HTML
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en" style="font-size: 16px;">
#  <head>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta charset="utf-8"/>
#   <meta content="​ SUMMER WORSHOP 2024" name="keywords"/>
#   <meta content="" name="description"/>
#   <title>
#    Home
#   </title>
#   <link href="nicepage.css" media="screen" rel="stylesheet"/>
#   <link href="Home.css" media="screen" rel="stylesheet"/>
#   <script class="u-script" defer="" src="jquery.js" type="text/javascript">
#   </script>
#   <script class="u-script" defer="" src="nicepage.js" type="text/javascript">
#   </script>
#   <meta content="Nicepage 6.4.0, nicepage.com" name="generator"/>
#   <link href="https://fonts.googleapis.com/css?family=Roboto:100,100i,300,300i,400,400i,500,500i,700,700i,900,900i|Open+Sans:300,300i,400,400i,500,500i,600,600i,700,700i,800,800i" id="u-theme-google-font" rel="stylesheet"/>
#   <link href="https://fonts.googleapis.com/css?family=Montserrat:100,100i,200,200i,300,300i,400,400i,500,500i,600,600i,700,700i,800,800i,900,900i|Comic+Neue:300,300i,400,400i,700,700i" id="u-page-google-font" rel="stylesheet"/>
#   <script type="application/ld+json">
#    {
# 		"@context": "http://schema.org",
# 		"@type": "Organization",
# 		"name": "Site2",
# 		"logo": "images/logo.png"
# }
#   </script>
#   <meta content="#478ac9" name="theme-color"/>
#   <meta content="Home" property="og:title"/>
#   <meta content="" property="og:description"/>
#   <meta content="website" property="og:type"/>
#   <meta data-intl-tel-input-cdn-path="intlTelInput/"/>
#  </head>
#  <body class="u-body u-xl-mode" data-home-page="Home.html" data-home-page-title="Home" data-include-products="false" data-lang="en" data-path-to-root="./">
#   <header class="u-border-no-bottom u-border-no-left u-border-no-right u-border-no-top u-clearfix u-header u-section-row-container" data-animation-delay="0" data-animation-direction="" data-animation-duration="0" data-animation-name="" id="sec-1cca" style="">
#    <div class="u-section-rows" style="">
#     <div class="u-clearfix u-section-row" data-animation-delay="0" data-animation-direction="" data-animation-duration="0" data-animation-name="" id="sec-781a">
#      <div class="u-clearfix u-sheet u-sheet-1">
#       <a class="u-align-left u-image u-logo u-image-1" data-image-height="115" data-image-width="644" href="https://www.comp.nus.edu.sg/" target="_blank" title="NUS School of Computing">
#        <img class="u-logo-image u-logo-image-1" src="images/logo.png"/>
#       </a>
#      </div>
#     </div>
#     <div class="u-section-row" id="sec-2aa7">
#      <div class="u-clearfix u-sheet u-valign-middle u-sheet-2">
#       <nav class="u-align-center-lg u-align-center-xl u-align-left-md u-align-left-sm u-align-left-xs u-menu u-menu-one-level u-offcanvas u-menu-1">
#        <div class="menu-collapse" style="font-size: 1rem; letter-spacing: 0px;">
#         <a class="u-button-style u-custom-left-right-menu-spacing u-custom-padding-bottom u-custom-top-bottom-menu-spacing u-nav-link u-text-active-palette-1-base u-text-hover-palette-2-base" href="#">
#          <svg class="u-svg-link" viewbox="0 0 24 24">
#           <use xlink:href="#svg-deba" xmlns:xlink="http://www.w3.org/1999/xlink">
#           </use>
#          </svg>
#          <svg class="u-svg-content" id="svg-deba" version="1.1" viewbox="0 0 16 16" x="0px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px">
#           <g>
#            <rect height="2" width="16" y="1">
#            </rect>
#            <rect height="2" width="16" y="7">
#            </rect>
#            <rect height="2" width="16" y="13">
#            </rect>
#           </g>
#          </svg>
#         </a>
#        </div>
#        <div class="u-custom-menu u-nav-container">
#         <ul class="u-nav u-unstyled u-nav-1">
#          <li class="u-nav-item">
#           <a class="u-button-style u-nav-link u-text-active-palette-1-base u-text-hover-palette-2-base" href="Home.html" style="padding: 10px 20px;">
#            Home
#           </a>
#          </li>
#          <li class="u-nav-item">
#           <a class="u-button-style u-nav-link u-text-active-palette-1-base u-text-hover-palette-2-base" href="Structure.html" style="padding: 10px 20px;">
#            Structure
#           </a>
#          </li>
#          <li class="u-nav-item">
#           <a class="u-button-style u-nav-link u-text-active-palette-1-base u-text-hover-palette-2-base" href="Courses.html" style="padding: 10px 20px;">
#            Courses
#           </a>
#          </li>
#          <li class="u-nav-item">
#           <a class="u-button-style u-nav-link u-text-active-palette-1-base u-text-hover-palette-2-base" href="Application.html" style="padding: 10px 20px;">
#            Application
#           </a>
#          </li>
#          <li class="u-nav-item">
#           <a class="u-button-style u-nav-link u-text-active-palette-1-base u-text-hover-palette-2-base" href="Testimonials.html" style="padding: 10px 20px;">
#            Testimonials
#           </a>
#          </li>
#          <li class="u-nav-item">
#           <a class="u-button-style u-nav-link u-text-active-palette-1-base u-text-hover-palette-2-base" href="Facilities.html" style="padding: 10px 20px;">
#            Facilities
#           </a>
#          </li>
#          <li class="u-nav-item">
#           <a class="u-button-style u-nav-link u-text-active-palette-1-base u-text-hover-palette-2-base" href="FAQ.html" style="padding: 10px 20px;">
#            FAQ
#           </a>
#          </li>
#          <li class="u-nav-item">
#           <a class="u-button-style u-nav-link u-text-active-palette-1-base u-text-hover-palette-2-base" href="Media.html" style="padding: 10px 20px;">
#            Media
#           </a>
#          </li>
#          <li class="u-nav-item">
#           <a class="u-button-style u-nav-link u-text-active-palette-1-base u-text-hover-palette-2-base" href="Contact.html" style="padding: 10px 20px;">
#            Contact
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="u-custom-menu u-nav-container-collapse">
#         <div class="u-black u-container-style u-inner-container-layout u-opacity u-opacity-95 u-sidenav">
#          <div class="u-inner-container-layout u-sidenav-overflow">
#           <div class="u-menu-close">
#           </div>
#           <ul class="u-align-center u-nav u-popupmenu-items u-unstyled u-nav-2">
#            <li class="u-nav-item">
#             <a class="u-button-style u-nav-link" href="Home.html">
#              Home
#             </a>
#            </li>
#            <li class="u-nav-item">
#             <a class="u-button-style u-nav-link" href="Structure.html">
#              Structure
#             </a>
#            </li>
#            <li class="u-nav-item">
#             <a class="u-button-style u-nav-link" href="Courses.html">
#              Courses
#             </a>
#            </li>
#            <li class="u-nav-item">
#             <a class="u-button-style u-nav-link" href="Application.html">
#              Application
#             </a>
#            </li>
#            <li class="u-nav-item">
#             <a class="u-button-style u-nav-link" href="Testimonials.html">
#              Testimonials
#             </a>
#            </li>
#            <li class="u-nav-item">
#             <a class="u-button-style u-nav-link" href="Facilities.html">
#              Facilities
#             </a>
#            </li>
#            <li class="u-nav-item">
#             <a class="u-button-style u-nav-link" href="FAQ.html">
#              FAQ
#             </a>
#            </li>
#            <li class="u-nav-item">
#             <a class="u-button-style u-nav-link" href="Media.html">
#              Media
#             </a>
#            </li>
#            <li class="u-nav-item">
#             <a class="u-button-style u-nav-link" href="Contact.html">
#              Contact
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="u-black u-menu-overlay u-opacity u-opacity-70">
#         </div>
#        </div>
#       </nav>
#      </div>
#     </div>
#    </div>
#   </header>
#   <section class="u-carousel u-slide u-block-6983-1" data-interval="5000" data-u-ride="carousel" id="carousel-d1a1">
#    <ol class="u-absolute-hcenter u-carousel-indicators u-block-6983-6">
#     <li class="u-active u-grey-30" data-u-slide-to="0" data-u-target="#carousel-d1a1">
#     </li>
#    </ol>
#    <div class="u-carousel-inner" role="listbox" style="">
#     <div class="custom-expanded u-active u-carousel-item u-clearfix u-image u-section-1-1" data-image-height="1080" data-image-width="1000">
#      <div class="u-clearfix u-sheet u-sheet-1">
#       <div class="u-container-style u-expanded-width u-gradient u-group u-shape-rectangle u-group-1">
#        <div class="u-container-layout u-container-layout-1">
#         <div class="u-align-center u-container-style u-group u-image u-image-round u-radius u-image-1" data-image-height="680" data-image-width="1330">
#          <div class="u-container-layout u-container-layout-2">
#           <h2 class="u-custom-font u-text u-text-default u-text-palette-1-dark-2 u-text-1">
#            <span class="u-icon">
#            </span>
#            SUMMER WORKSHOP 2024
#           </h2>
#          </div>
#         </div>
#         <span class="u-border-3 u-border-palette-1-dark-1 u-custom-color-1 u-file-icon u-icon u-icon-rounded u-text-white u-icon-2" data-href="FAQ.html">
#          <img alt="" src="images/3686883-d3c938bd.png"/>
#         </span>
#         <p class="u-text u-text-default u-text-palette-1-dark-2 u-text-2">
#          FAQ
#         </p>
#         <span class="u-border-3 u-border-palette-1-dark-1 u-custom-color-1 u-file-icon u-icon u-icon-rounded u-icon-3" data-href="Courses.html">
#          <img alt="" src="images/4762250-9762e9fa.png"/>
#         </span>
#         <span class="u-border-3 u-border-palette-1-dark-1 u-custom-color-1 u-file-icon u-icon u-icon-rounded u-text-white u-icon-4" data-href="Facilities.html">
#          <img alt="" src="images/3333828-c9a61b33.png"/>
#         </span>
#         <p class="u-text u-text-default u-text-palette-1-dark-2 u-text-3">
#          facilities
#         </p>
#         <span class="u-border-3 u-border-palette-1-dark-1 u-custom-color-1 u-file-icon u-flip-horizontal u-icon u-icon-rectangle u-icon-5" data-href="Structure.html">
#          <img alt="" src="images/808497-9e651630.png"/>
#         </span>
#         <span class="u-border-3 u-border-palette-1-dark-1 u-custom-color-1 u-file-icon u-icon u-icon-rectangle u-icon-6" data-href="Home.html">
#          <img alt="" src="images/3388845-dca7ad7c.png"/>
#         </span>
#         <p class="u-text u-text-default u-text-palette-1-dark-2 u-text-4">
#          STRUCTURE
#          <span style="font-weight: 700;">
#          </span>
#         </p>
#         <p class="u-text u-text-default u-text-palette-1-dark-2 u-text-5">
#          Courses
#         </p>
#         <span class="u-border-3 u-border-palette-1-dark-1 u-custom-color-1 u-file-icon u-icon u-icon-rounded u-icon-7" data-href="Testimonials.html">
#          <img alt="" src="images/11213197-cd544380.png"/>
#         </span>
#         <span class="u-border-3 u-border-palette-1-dark-1 u-custom-color-1 u-file-icon u-icon u-icon-8" data-href="Media.html">
#          <img alt="" src="images/7615074-9fbbc056.png"/>
#         </span>
#         <p class="u-text u-text-default u-text-palette-1-dark-2 u-text-6">
#          <span style="font-weight: 700;">
#           Media
#          </span>
#         </p>
#         <span class="u-border-3 u-border-palette-1-dark-1 u-custom-color-1 u-file-icon u-icon u-text-white u-icon-9" data-href="Application.html">
#          <img alt="" src="images/942799-a4d9bb95.png"/>
#         </span>
#         <span class="u-border-3 u-border-palette-1-dark-1 u-custom-color-1 u-file-icon u-icon u-icon-rounded u-icon-10" data-href="Contact.html">
#          <img alt="" src="images/2354103-24e16266.png"/>
#         </span>
#         <p class="u-text u-text-default u-text-palette-1-dark-2 u-text-7">
#          CONTACT
#         </p>
#         <p class="u-text u-text-palette-1-dark-2 u-text-8">
#          HO​ME
#         </p>
#         <p class="u-text u-text-default u-text-palette-1-dark-2 u-text-9">
#          applica​tion
#         </p>
#         <p class="u-align-center u-text u-text-default u-text-palette-1-dark-2 u-text-10">
#          Testimonials
#         </p>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <a class="u-carousel-control u-carousel-control-prev u-hidden u-icon-rectangle u-text-custom-color-2 u-block-6983-5" data-u-slide="prev" href="#carousel-d1a1" role="button">
#     <span aria-hidden="true">
#      <svg class="u-svg-link" viewbox="0 0 477.175 477.175">
#       <path d="M145.188,238.575l215.5-215.5c5.3-5.3,5.3-13.8,0-19.1s-13.8-5.3-19.1,0l-225.1,225.1c-5.3,5.3-5.3,13.8,0,19.1l225.1,225
#                     c2.6,2.6,6.1,4,9.5,4s6.9-1.3,9.5-4c5.3-5.3,5.3-13.8,0-19.1L145.188,238.575z">
#       </path>
#      </svg>
#     </span>
#     <span class="sr-only">
#      Previous
#     </span>
#    </a>
#    <a class="u-absolute-vcenter u-carousel-control u-carousel-control-next u-hidden u-icon-rectangle u-text-custom-color-2 u-block-6983-4" data-u-slide="next" href="#carousel-d1a1" role="button">
#     <span aria-hidden="true">
#      <svg class="u-svg-link" viewbox="0 0 477.175 477.175">
#       <path d="M360.731,229.075l-225.1-225.1c-5.3-5.3-13.8-5.3-19.1,0s-5.3,13.8,0,19.1l215.5,215.5l-215.5,215.5
#                     c-5.3,5.3-5.3,13.8,0,19.1c2.6,2.6,6.1,4,9.5,4c3.4,0,6.9-1.3,9.5-4l225.1-225.1C365.931,242.875,365.931,234.275,360.731,229.075z">
#       </path>
#      </svg>
#     </span>
#     <span class="sr-only">
#      Next
#     </span>
#    </a>
#   </section>
#   <section class="u-clearfix u-white u-section-2" id="sec-a571">
#    <div class="u-clearfix u-sheet u-valign-middle-xs u-sheet-1">
#     <div class="custom-expanded data-layout-selected u-clearfix u-gutter-10 u-layout-wrap u-layout-wrap-1">
#      <div class="u-gutter-0 u-layout">
#       <div class="u-layout-col">
#        <div class="u-container-style u-layout-cell u-size-60 u-layout-cell-1">
#         <div class="u-container-layout u-valign-top u-container-layout-1">
#          <h2 class="u-align-left u-text u-text-custom-color-3 u-text-default u-text-1">
#           About
#          </h2>
#          <p class="u-align-center u-text u-text-2">
#           The National University of Singapore (NUS) School of Computing (SOC) Summer Workshop 2024 is the sixth edition of a workshop-based programme organized by NUS, School of Computing.
#           <br/>
#           <br/>
#           It is open to undergraduates from all across the world majoring in Computer Science, Information Systems and other related disciplines.
#           <br/>
#           <br/>
#           The workshop will explore some of today's most highly sought-after skills and knowledge in computing (e.g. Artificial Intelligence, Cloud Computing, Visual Computing, Robotics and Deep Learning, Game development, Analytics, Media and IoT). Through a blend of highly-interactive classes and projects, workshop participants will have an immersive learning experience, integrating theory into practice through hands-on application.
#           <br/>
#          </p>
#          <a class="u-btn u-btn-round u-button-style u-file-link u-radius-50 u-btn-1" href="files/SWS2024_290224.pdf" target="_blank">
#           Click to view promotional slides
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="u-carousel u-expanded-width u-gallery u-gallery-slider u-layout-carousel u-lightbox u-no-transition u-show-text-on-hover u-gallery-1" data-interval="5000" data-u-ride="carousel" id="carousel-88f0">
#      <ol class="u-absolute-hcenter u-carousel-indicators u-carousel-indicators-1">
#       <li class="u-active u-grey-70 u-shape-circle" data-u-slide-to="0" data-u-target="#carousel-88f0" style="width: 10px; height: 10px;">
#       </li>
#       <li class="u-grey-70 u-shape-circle" data-u-slide-to="1" data-u-target="#carousel-88f0" style="width: 10px; height: 10px;">
#       </li>
#      </ol>
#      <div class="u-carousel-inner u-gallery-inner" role="listbox">
#       <div class="u-active u-carousel-item u-effect-fade u-effect-hover-zoom u-gallery-item u-carousel-item-1">
#        <div class="u-back-slide" data-image-height="566" data-image-width="1080">
#         <img class="u-back-image u-expanded" src="images/FarewellDinnerGroupshot_Resized.png"/>
#        </div>
#        <div class="u-align-center u-over-slide u-shading u-valign-bottom u-over-slide-1">
#        </div>
#       </div>
#       <div class="u-carousel-item u-effect-fade u-effect-hover-zoom u-gallery-item u-carousel-item-2">
#        <div class="u-back-slide" data-image-height="1126" data-image-width="2001">
#         <img class="u-back-image u-expanded u-back-image-2" src="images/20190225_School_Facade_About_Page.jpg"/>
#        </div>
#        <div class="u-align-center u-over-slide u-shading u-valign-bottom u-over-slide-2">
#        </div>
#       </div>
#      </div>
#      <a class="u-absolute-vcenter u-carousel-control u-carousel-control-prev u-grey-70 u-icon-circle u-opacity u-opacity-70 u-spacing-10 u-text-white u-carousel-control-1" data-u-slide="prev" href="#carousel-88f0" role="button">
#       <span aria-hidden="true">
#        <svg viewbox="0 0 451.847 451.847">
#         <path d="M97.141,225.92c0-8.095,3.091-16.192,9.259-22.366L300.689,9.27c12.359-12.359,32.397-12.359,44.751,0
# c12.354,12.354,12.354,32.388,0,44.748L173.525,225.92l171.903,171.909c12.354,12.354,12.354,32.391,0,44.744
# c-12.354,12.365-32.386,12.365-44.745,0l-194.29-194.281C100.226,242.115,97.141,234.018,97.141,225.92z">
#         </path>
#        </svg>
#       </span>
#       <span class="sr-only">
#        <svg viewbox="0 0 451.847 451.847">
#         <path d="M97.141,225.92c0-8.095,3.091-16.192,9.259-22.366L300.689,9.27c12.359-12.359,32.397-12.359,44.751,0
# c12.354,12.354,12.354,32.388,0,44.748L173.525,225.92l171.903,171.909c12.354,12.354,12.354,32.391,0,44.744
# c-12.354,12.365-32.386,12.365-44.745,0l-194.29-194.281C100.226,242.115,97.141,234.018,97.141,225.92z">
#         </path>
#        </svg>
#       </span>
#      </a>
#      <a class="u-absolute-vcenter u-carousel-control u-carousel-control-next u-grey-70 u-icon-circle u-opacity u-opacity-70 u-spacing-10 u-text-white u-carousel-control-2" data-u-slide="next" href="#carousel-88f0" role="button">
#       <span aria-hidden="true">
#        <svg viewbox="0 0 451.846 451.847">
#         <path d="M345.441,248.292L151.154,442.573c-12.359,12.365-32.397,12.365-44.75,0c-12.354-12.354-12.354-32.391,0-44.744
# L278.318,225.92L106.409,54.017c-12.354-12.359-12.354-32.394,0-44.748c12.354-12.359,32.391-12.359,44.75,0l194.287,194.284
# c6.177,6.18,9.262,14.271,9.262,22.366C354.708,234.018,351.617,242.115,345.441,248.292z">
#         </path>
#        </svg>
#       </span>
#       <span class="sr-only">
#        <svg viewbox="0 0 451.846 451.847">
#         <path d="M345.441,248.292L151.154,442.573c-12.359,12.365-32.397,12.365-44.75,0c-12.354-12.354-12.354-32.391,0-44.744
# L278.318,225.92L106.409,54.017c-12.354-12.359-12.354-32.394,0-44.748c12.354-12.359,32.391-12.359,44.75,0l194.287,194.284
# c6.177,6.18,9.262,14.271,9.262,22.366C354.708,234.018,351.617,242.115,345.441,248.292z">
#         </path>
#        </svg>
#       </span>
#      </a>
#     </div>
#    </div>
#   </section>
#   <section class="u-clearfix u-section-3" id="sec-96ae">
#    <div class="u-clearfix u-sheet u-valign-middle-lg u-valign-middle-md u-sheet-1">
#     <h2 class="u-align-center u-text u-text-default u-text-1">
#      Program Schedule
#     </h2>
#     <img class="u-expanded-width-lg u-expanded-width-md u-expanded-width-sm u-expanded-width-xs u-image u-image-contain u-image-1" data-image-height="450" data-image-width="867" src="images/SWS2024ProgramScheduleP1.png"/>
#    </div>
#   </section>
#   <section class="u-clearfix u-section-4" id="sec-7626">
#    <div class="u-clearfix u-sheet u-sheet-1">
#     <img class="u-expanded-width-lg u-expanded-width-md u-expanded-width-sm u-expanded-width-xs u-image u-image-contain u-image-1" data-image-height="582" data-image-width="834" src="images/SWS2024ProgramScheduleP2.png"/>
#     <a class="u-btn u-btn-round u-button-style u-file-link u-radius u-btn-1" href="files/SWS2024ProgramSchedule.pdf" target="_blank">
#      Click to download Programme Schedule
#     </a>
#    </div>
#   </section>
#   <section class="u-align-left u-clearfix u-image u-section-5" data-image-height="807" data-image-width="1000" id="sec-754a">
#    <div class="u-clearfix u-sheet u-valign-middle-lg u-valign-middle-md u-valign-middle-sm u-valign-middle-xs u-sheet-1">
#     <div class="u-container-style u-expanded-width u-group u-opacity u-opacity-80 u-shape-rectangle u-white u-group-1">
#      <div class="u-container-layout u-container-layout-1">
#       <h2 class="u-align-center u-text u-text-custom-color-3 u-text-default u-text-1">
#        Highlights
#       </h2>
#      </div>
#     </div>
#     <div class="u-expanded-width u-list u-list-1">
#      <div class="u-repeater u-repeater-1">
#       <div class="u-align-center u-container-style u-list-item u-repeater-item u-shape-rectangle u-white u-list-item-1">
#        <div class="u-container-layout u-similar-container u-container-layout-2">
#         <span class="u-icon u-icon-circle u-palette-1-base u-text-white u-icon-1">
#          <svg class="u-svg-link" preserveaspectratio="xMidYMin slice" style="" viewbox="0 0 128 128">
#           <use xlink:href="#svg-caaf" xmlns:xlink="http://www.w3.org/1999/xlink">
#           </use>
#          </svg>
#          <svg class="u-svg-content" id="svg-caaf" viewbox="0 0 128 128">
#           <polygon points="104 40 104 48 120 48 120 120 48 120 48 104 40 104 40 128 128 128 128 40">
#           </polygon>
#           <rect height="8" width="8" x="80">
#           </rect>
#           <rect height="8" width="8" x="16">
#           </rect>
#           <rect height="8" width="8" x="32">
#           </rect>
#           <rect height="8" width="8" x="16" y="80">
#           </rect>
#           <rect height="8" width="8" x="48">
#           </rect>
#           <rect height="8" width="8" x="64">
#           </rect>
#           <rect height="8" width="8">
#           </rect>
#           <rect height="8" width="8" y="48">
#           </rect>
#           <rect height="8" width="8" y="64">
#           </rect>
#           <rect height="8" width="8" y="32">
#           </rect>
#           <rect height="8" width="8" y="16">
#           </rect>
#           <rect height="8" width="8" x="80" y="16">
#           </rect>
#           <rect height="8" width="8" y="80">
#           </rect>
#           <path d="m63.6 96.8 10.4 10.4 36.8-36.8-10.6-10.6-5.7-17-19.6-19.5-39.5 16.2c-6.1 2.5-9.1 9.5-6.5 15.7l0.3 0.6-0.5 0.5c-6.2 6.2-6.2 16.4 0 22.6l15.1 15.1 19.8 2.8zm-31.6-29.2c0-2.1 0.8-4.2 2.3-5.7l14.1 14.1 5.7-5.7-17-17c-1.6-1.6-1.6-4.1 0-5.7 0.4-0.4 0.8-0.7 1.3-0.9l34.6-14 14.4 14.4 5.7 17 6.3 6.3-25.5 25.5-6.6-6.6-19.8-2.8-13.2-13.3c-1.5-1.5-2.3-3.5-2.3-5.6z">
#           </path>
#          </svg>
#         </span>
#         <h3 class="u-text u-text-custom-color-1 u-text-2">
#          Abundant Choices
#         </h3>
#         <p class="u-text u-text-3">
#          Wide range of subjects offered across
#          <b>
#           3 clusters
#          </b>
#          with
#          <b>
#           15 unique courses
#          </b>
#          in total to build your knowledge in high-demand
# IT fields.
#         </p>
#        </div>
#       </div>
#       <div class="u-align-center u-container-style u-list-item u-repeater-item u-shape-rectangle u-white u-list-item-2">
#        <div class="u-container-layout u-similar-container u-container-layout-3">
#         <span class="u-file-icon u-icon u-icon-circle u-palette-1-base u-text-white u-icon-2">
#          <img alt="" src="images/3024605-d20e136b.png"/>
#         </span>
#         <h3 class="u-text u-text-custom-color-1 u-text-4">
#          NUS Account
#         </h3>
#         <p class="u-text u-text-5">
#          Each participant will receive an NUS account to access the
#          <b>
#           learning platforms used by NUS
#          </b>
#          (e.g. Canvas, Zoom).
#         </p>
#        </div>
#       </div>
#       <div class="u-align-center u-container-style u-list-item u-repeater-item u-shape-rectangle u-white u-list-item-3">
#        <div class="u-container-layout u-similar-container u-container-layout-4">
#         <span class="u-icon u-icon-circle u-palette-1-base u-text-white u-icon-3">
#          <svg class="u-svg-link" preserveaspectratio="xMidYMin slice" style="" viewbox="0 0 128 128">
#           <use xlink:href="#svg-5300" xmlns:xlink="http://www.w3.org/1999/xlink">
#           </use>
#          </svg>
#          <svg class="u-svg-content" id="svg-5300" viewbox="0 0 128 128">
#           <path d="m40.6 11c2.3 0 4.4 0.9 6.1 2.5 5.4 5.4 10.8 19.2 8.9 21.2 0 0-0.3 0.3-1.5 0.3-5.5 0-16.1-5.7-19.5-9.2-3.4-3.4-3.4-8.9 0-12.2 1.5-1.7 3.7-2.6 6-2.6m46.8 0.1c2.2 0 4.4 0.8 6.1 2.4 3.4 3.4 3.4 8.9 0 12.2-3.4 3.5-14 9.2-19.5 9.2-1.1 0-1.5-0.3-1.5-0.3-1.9-1.9 3.5-15.7 8.9-21.2 1.6-1.5 3.8-2.3 6-2.3m32.6 32.1v16h-52v-16h52m-60 0v16h-52v-16h52m52 23.9v47.9h-44v-47.9h44m-52 0v47.9h-44v-47.9h44m-19.4-64.1c-4.4 0-8.6 1.7-11.7 4.9-6.5 6.5-6.5 17 0 23.5 1.2 1.2 2.8 2.5 4.7 3.8h-25.6c-4.4 0-8 3.6-8 8v24h8v55.8h112v-55.9h8v-24c0-4.4-3.6-8-8-8h-25.6c1.9-1.3 3.6-2.6 4.7-3.8 6.5-6.5 6.5-17 0-23.5-3-3-7.3-4.8-11.7-4.8s-8.7 1.7-11.7 4.8c-4.6 4.6-7.8 11.7-8.9 14.5-2.2 5.4-3 9.5-2.5 12.8h-0.5c0.5-3.2-0.4-7.4-2.5-12.8-1.2-2.8-4.3-9.9-8.9-14.5-3.2-3.1-7.4-4.8-11.8-4.8z">
#           </path>
#          </svg>
#         </span>
#         <h3 class="u-text u-text-custom-color-1 u-text-6">
#          Project Competition
#         </h3>
#         <p class="u-text u-text-7">
#          A project competition at the end of the workshop to showcase your computing skills ​through
#          <b>
#           intensive hands-on project
#          </b>
#          supervised by our esteemed professors.
#         </p>
#        </div>
#       </div>
#       <div class="u-align-center u-container-style u-list-item u-repeater-item u-shape-rectangle u-white u-list-item-4">
#        <div class="u-container-layout u-similar-container u-container-layout-5">
#         <span class="u-file-icon u-icon u-icon-circle u-palette-1-base u-text-white u-icon-4">
#          <img alt="" src="images/1021129-ccaedb21.png"/>
#         </span>
#         <h3 class="u-text u-text-custom-color-1 u-text-8">
#          Certificate
#         </h3>
#         <p class="u-text u-text-9">
#          Certificate greatly advantageous for future career and further studies.
#         </p>
#        </div>
#       </div>
#       <div class="u-align-center u-container-style u-list-item u-repeater-item u-shape-rectangle u-white u-list-item-5">
#        <div class="u-container-layout u-similar-container u-container-layout-6">
#         <span class="u-file-icon u-icon u-icon-circle u-palette-1-base u-text-white u-icon-5">
#          <img alt="" src="images/11617569-18886d54.png"/>
#         </span>
#         <h3 class="u-text u-text-custom-color-1 u-text-10">
#          NGNE Programme
#         </h3>
#         <p class="u-text u-text-11">
#          Be eligible to apply for the
#          <b>
#           SoC NGNE Programme
#          </b>
#          which offers a chance for direct admission to
#          <b>
#           Master of Computing/PhD.
#          </b>
#         </p>
#        </div>
#       </div>
#       <div class="u-align-center u-container-style u-list-item u-repeater-item u-shape-rectangle u-white u-list-item-6">
#        <div class="u-container-layout u-similar-container u-container-layout-7">
#         <span class="u-icon u-icon-circle u-palette-1-base u-text-white u-icon-6">
#          <svg class="u-svg-link" preserveaspectratio="xMidYMin slice" style="" viewbox="0 0 128 128">
#           <use xlink:href="#svg-96cd" xmlns:xlink="http://www.w3.org/1999/xlink">
#           </use>
#          </svg>
#          <svg class="u-svg-content" id="svg-96cd" viewbox="0 0 128 128">
#           <path d="m44.1 63.9h39.8c4.6 0 8.4-3.9 8.4-8.8v-1.8c0-5.6-2.8-10.7-7.3-13.3-2.4-1.4-5.4-2.9-8.8-4.1 2.8-3 4.6-6.9 4.6-11.3-0.1-9.2-7.6-16.6-16.8-16.6s-16.7 7.4-16.7 16.5c0 4.4 1.7 8.4 4.6 11.3-3.4 1.2-6.5 2.7-8.8 4.1-4.5 2.7-7.3 7.7-7.3 13.3v1.8c-0.1 4.9 3.7 8.9 8.3 8.9zm19.9-48c4.8 0 8.7 3.9 8.7 8.6 0 4.8-3.9 8.6-8.7 8.6s-8.7-3.9-8.7-8.6 3.9-8.6 8.7-8.6zm-20.3 37.3c0-2.7 1.3-5.3 3.4-6.5 4-2.3 10.2-5.1 16.9-5.1s12.9 2.8 16.9 5.1c2.1 1.2 3.4 3.8 3.4 6.5v1.8c0 0.6-0.3 0.9-0.4 0.9h-39.8c-0.1 0-0.4-0.3-0.4-0.9v-1.8zm5.5 40.9c-2.4-1.4-5.4-2.9-8.8-4.1 2.8-3 4.6-7 4.6-11.3 0-9.1-7.5-16.5-16.7-16.5s-16.7 7.4-16.7 16.5c0 4.4 1.7 8.4 4.6 11.3-3.4 1.2-6.5 2.7-8.8 4.1-4.6 2.6-7.4 7.7-7.4 13.3v1.8c0 4.9 3.8 8.8 8.4 8.8h39.8c4.6 0 8.4-3.9 8.4-8.8v-1.8c0-5.6-2.8-10.7-7.4-13.3zm-20.9-24.1c4.8 0 8.7 3.9 8.7 8.6 0 4.8-3.9 8.6-8.7 8.6s-8.7-3.9-8.7-8.6 3.9-8.6 8.7-8.6zm20.3 39.2c0 0.6-0.3 0.9-0.4 0.9h-39.8c-0.1 0-0.4-0.3-0.4-0.9v-1.8c0-2.7 1.3-5.3 3.4-6.5 4-2.3 10.2-5.1 16.9-5.1s12.9 2.8 16.9 5.1c2.1 1.2 3.4 3.8 3.4 6.5v1.8zm72.1-15.1c-2.4-1.4-5.4-2.9-8.8-4.1 2.8-3 4.6-6.9 4.6-11.3 0-9.1-7.5-16.5-16.7-16.5s-16.7 7.4-16.7 16.5c-0.1 4.3 1.7 8.3 4.5 11.3-3.4 1.2-6.5 2.7-8.8 4.1-4.5 2.7-7.3 7.7-7.3 13.3v1.8c0 4.9 3.8 8.8 8.4 8.8h39.8c4.6 0 8.4-3.9 8.4-8.8v-1.8c-0.1-5.6-2.9-10.7-7.4-13.3zm-21-24.1c4.8 0 8.7 3.9 8.7 8.6 0 4.8-3.9 8.6-8.7 8.6s-8.7-3.9-8.7-8.6 3.9-8.6 8.7-8.6zm20.3 39.2c0 0.6-0.3 0.9-0.4 0.9h-39.8c-0.1 0-0.4-0.3-0.4-0.9v-1.8c0-2.7 1.3-5.3 3.4-6.5 4-2.3 10.2-5.1 16.9-5.1s12.9 2.8 16.9 5.1c2.1 1.2 3.4 3.8 3.4 6.5v1.8z">
#           </path>
#          </svg>
#         </span>
#         <h3 class="u-text u-text-custom-color-1 u-text-12">
#          Internship
#         </h3>
#         <p class="u-text u-text-13">
#          <b>
#           Internship
#          </b>
#          opportunities available to participants of the Summer Workshop on a competitive basis
#         </p>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </section>
#   <section class="u-align-center u-clearfix u-section-6" id="sec-8e8d">
#    <div class="u-clearfix u-sheet u-sheet-1">
#     <div class="u-align-left u-container-style u-expanded-width u-group u-shape-rectangle u-white u-group-1">
#      <div class="u-container-layout u-container-layout-1">
#       <h2 class="u-align-center u-text u-text-custom-color-3 u-text-1">
#        What you will receive
#       </h2>
#       <p class="u-align-left u-text u-text-2">
#        Upon successful completion of the Summer Workshop,
#        <b>
#         <u>
#          EACH
# PARTICIPANT
#         </u>
#        </b>
#        will receive:
#       </p>
#       <p class="u-align-left u-text u-text-3">
#        <b>
#         <u>
#          WINNING PROJECT TEAMS
#         </u>
#        </b>
#        will receive:
#       </p>
#      </div>
#     </div>
#     <div class="custom-expanded data-layout-selected u-clearfix u-layout-wrap u-layout-wrap-1">
#      <div class="u-layout" style="">
#       <div class="u-layout-row" style="">
#        <div class="u-container-style u-layout-cell u-size-15 u-layout-cell-1">
#         <div class="u-container-layout u-container-layout-2">
#          <span class="u-align-center u-file-icon u-icon u-text-custom-color-2 u-icon-1">
#           <img alt="" src="images/73524-4b72898e.png"/>
#          </span>
#          <p class="u-align-center u-text u-text-4">
#           <span class="u-text-custom-color-1">
#            Completion
#           </span>
#           <span class="u-text-custom-color-1">
#            Certificate
#           </span>
#          </p>
#          <p class="u-align-center u-text u-text-5">
#           To certify that you have completed the NUS SOC Summer Workshop satisfactorily
#          </p>
#         </div>
#        </div>
#        <div class="u-container-style u-layout-cell u-size-15 u-layout-cell-2">
#         <div class="u-container-layout u-valign-top u-container-layout-3">
#          <span class="u-align-center u-file-icon u-icon u-text-custom-color-4 u-icon-2">
#           <img alt="" src="images/3712378-96bbd644.png"/>
#          </span>
#          <p class="u-align-center u-text u-text-custom-color-1 u-text-default u-text-6">
#           Performance Slip
#          </p>
#          <p class="u-align-center u-text u-text-7">
#           To indicate your performance throughout the Summer Workshop with a letter grade
#          </p>
#         </div>
#        </div>
#        <div class="u-container-style u-layout-cell u-size-15 u-layout-cell-3">
#         <div class="u-container-layout u-valign-top u-container-layout-4">
#          <img alt="" class="u-align-center u-image u-image-contain u-image-default u-preserve-proportions u-image-1" data-image-height="512" data-image-width="512" src="images/polo-shirt.png"/>
#          <p class="u-align-center u-text u-text-custom-color-1 u-text-default u-text-8">
#           Souvenir T-shirt
#          </p>
#          <p class="u-align-center u-text u-text-9">
#           An actual T-shirt specially designed for our Summer Workshop participants
#          </p>
#         </div>
#        </div>
#        <div class="u-container-style u-layout-cell u-size-15 u-layout-cell-4">
#         <div class="u-container-layout u-container-layout-5">
#          <span class="u-align-center u-file-icon u-icon u-text-custom-color-4 u-icon-3">
#           <img alt="" src="images/8199093-a72a05d1.png"/>
#          </span>
#          <p class="u-align-center u-text u-text-custom-color-1 u-text-default u-text-10">
#           EZ-Link Card
#          </p>
#          <p class="u-align-center u-text u-text-11">
#           An EZ-Link Card (Singapore public transport card) with stored value and a unique Summer Workshop design
#          </p>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="data-layout-selected u-clearfix u-expanded-width u-gutter-0 u-layout-wrap u-layout-wrap-2">
#      <div class="u-layout">
#       <div class="u-layout-row">
#        <div class="u-container-style u-layout-cell u-size-15 u-layout-cell-5">
#         <div class="u-container-layout u-container-layout-6">
#          <span class="u-align-center u-file-icon u-icon u-text-custom-color-2 u-icon-4">
#           <img alt="" src="images/1445171-9dc0b4f5.png"/>
#          </span>
#          <p class="u-align-center u-text u-text-12">
#           <font color="#ff8c00">
#            Award Certificate
#           </font>
#          </p>
#          <p class="u-align-center u-text u-text-13">
#           To highlight your project achievements
#          </p>
#         </div>
#        </div>
#        <div class="u-container-style u-layout-cell u-size-15 u-layout-cell-6">
#         <div class="u-container-layout u-container-layout-7">
#          <span class="u-align-center-sm u-align-center-xs u-file-icon u-icon u-text-custom-color-4 u-icon-5">
#           <img alt="" src="images/726532-3f495c45.png"/>
#          </span>
#          <p class="u-align-center u-text u-text-14">
#           <font color="#ff8c00">
#            Attractive Prizes
#           </font>
#          </p>
#          <p class="u-align-center u-text u-text-15">
#           Mysterious gifts to be awarded to winning project teams in the final showcase on the last day of the workshop
#          </p>
#         </div>
#        </div>
#        <div class="u-container-style u-layout-cell u-size-15 u-layout-cell-7">
#         <div class="u-container-layout u-valign-bottom-lg u-valign-bottom-xl u-container-layout-8">
#          <img alt="" class="custom-expanded u-align-center u-image u-image-contain u-image-default u-image-2" data-image-height="507" data-image-width="439" src="images/PerformanceSlipSample.png"/>
#         </div>
#        </div>
#        <div class="u-container-style u-layout-cell u-size-15 u-layout-cell-8">
#         <div class="u-container-layout u-container-layout-9">
#          <img class="u-expanded-width-lg u-expanded-width-xl u-image u-image-contain u-image-3" data-image-height="393" data-image-width="495" src="images/CertificateSample.png"/>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </section>
#   <footer class="u-align-center u-clearfix u-custom-color-4 u-footer u-footer" id="sec-94d4">
#    <div class="u-clearfix u-sheet u-sheet-1">
#     <p class="u-align-center-md u-align-center-sm u-align-center-xs u-custom-font u-font-montserrat u-text u-text-default u-text-1">
#      National University of Singapore
#      <br/>
#      School of Computing
#     </p>
#     <p class="u-align-center-md u-align-center-sm u-align-center-xs u-custom-font u-font-montserrat u-text u-text-default u-text-2">
#      <span class="u-icon">
#       <svg class="u-svg-content" style="width: 1em; height: 1em;" viewbox="0 0 54.757 54.757" x="0px" y="0px">
#        <path d="M40.94,5.617C37.318,1.995,32.502,0,27.38,0c-5.123,0-9.938,1.995-13.56,5.617c-6.703,6.702-7.536,19.312-1.804,26.952
# 	L27.38,54.757L42.721,32.6C48.476,24.929,47.643,12.319,40.94,5.617z M27.557,26c-3.859,0-7-3.141-7-7s3.141-7,7-7s7,3.141,7,7
# 	S31.416,26,27.557,26z">
#        </path>
#       </svg>
#      </span>
#      COM1, 13 Computing Drive, Singapore 117417
#     </p>
#     <p class="u-align-center-md u-align-center-sm u-align-center-xs u-custom-font u-font-montserrat u-text u-text-default u-text-3">
#      <span class="u-file-icon u-icon u-text-white u-icon-2">
#       <img alt="" src="images/542638-2b75d781.png"/>
#      </span>
#      <a class="u-active-none u-border-none u-btn u-button-link u-button-style u-hover-none u-none u-text-palette-1-base u-btn-1" href="https://nicepage.com/c/real-estate-website-templates">
#       sws.comp.nus.edu.sg
#      </a>
#     </p>
#    </div>
#   </footer>
#  </body>
# </html>

# %%
text = soup.text.strip()
texts.append(text)
text
# Out:
# "Home\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nHome\nStructure\nCourses\nApplication\nTestimonials\nFacilities\nFAQ\nMedia\nContact\n\n\n\n\n\n\nHome\nStructure\nCourses\nApplication\nTestimonials\nFacilities\nFAQ\nMedia\nContact\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\xa0SUMMER WORKSHOP 2024\n                    \n\n\nFAQ\nfacilities\nSTRUCTURE\n\nCourses\n\nMedia\n\nCONTACT\nHO\u200bME\napplica\u200btion\nTestimonials\n\n\n\n\n\n\n\n\n\nPrevious\n\n\n\n\n\nNext\n\n\n\n\n\n\n\n\n\nAbout\nThe National University of Singapore (NUS) School of Computing (SOC) Summer Workshop 2024 is the sixth edition of a workshop-based programme organized by NUS, School of Computing.\nIt is open to undergraduates from all across the world majoring in Computer Science, Information Systems and other related disciplines.\nThe workshop will explore some of today's most highly sought-after skills and knowledge in computing (e.g. Artificial Intelligence, Cloud Computing, Visual Computing, Robotics and Deep Learning, Game development, Analytics, Media and IoT).\xa0Through a blend of highly-interactive classes and projects, workshop participants will have an immersive learning experience, integrating theory into practice through hands-on application.\n\nClick to view promotional slides\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nProgram Schedule\n\n\n\n\n\n\nClick to download Programme Schedule\n\n\n\n\n\n\nHighlights\n\n\n\n\n\n\n\nAbundant Choices\n Wide range of subjects offered across 3 clusters with 15 unique courses in total to build your knowledge in high-demand\nIT fields.\n                \n\n\n\n\nNUS Account\n Each participant will receive an NUS account to access the\xa0learning platforms used by NUS\xa0(e.g. Canvas, Zoom).\n                \n\n\n\n\n\nProject Competition\n A project competition at the end of the workshop to showcase your computing skills \u200bthrough\xa0intensive hands-on project\xa0supervised by our esteemed professors.\n                \n\n\n\n\nCertificate\n Certificate greatly advantageous for future career and further studies.\xa0\n\n\n\n\nNGNE Programme\n Be eligible to apply for the\xa0SoC NGNE Programme\xa0which offers a chance for direct admission to\xa0Master of Computing/PhD.\n\n\n\n\n\n\nInternship\nInternship\xa0opportunities\xa0available to participants of the Summer Workshop on a competitive basis\n                \n\n\n\n\n\n\n\n\n\n\nWhat you will receive\n Upon successful completion of the Summer Workshop,\xa0EACH\nPARTICIPANT\xa0will receive:\n            \nWINNING PROJECT TEAMS\xa0will receive:\xa0\xa0\n            \n\n\n\n\n\n\n\n\nCompletion \nCertificate\n\n To certify that you have completed the NUS SOC Summer Workshop satisfactorily\n\n\n\n\nPerformance Slip\n To indicate your performance throughout the Summer Workshop with a letter grade\n\n\n\n\n\nSouvenir T-shirt\n An actual T-shirt specially designed for our Summer Workshop participants\n\n\n\n\nEZ-Link Card\n An EZ-Link Card (Singapore public transport card) with stored value and a unique Summer Workshop design\n\n\n\n\n\n\n\n\n\n\n\nAward Certificate\n\nTo highlight your project achievements\n\n\n\n\n\nAttractive Prizes\n\n Mysterious gifts to be awarded to winning project teams in the final showcase on the last day of the workshop\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nNational University of SingaporeSchool of Computing\n        \n COM1, 13 Computing Drive, Singapore 117417\n        \n \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0sws.comp.nus.edu.sg"

# %%
#find all links
links = soup.find_all('a')
links
# Out:
# [<a class="u-align-left u-image u-logo u-image-1" data-image-height="115" data-image-width="644" href="https://www.comp.nus.edu.sg/" target="_blank" title="NUS School of Computing">
#  <img class="u-logo-image u-logo-image-1" src="images/logo.png"/>
#  </a>,
#  <a class="u-button-style u-custom-left-right-menu-spacing u-custom-padding-bottom u-custom-top-bottom-menu-spacing u-nav-link u-text-active-palette-1-base u-text-hover-palette-2-base" href="#">
#  <svg class="u-svg-link" viewbox="0 0 24 24"><use xlink:href="#svg-deba" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
#  <svg class="u-svg-content" id="svg-deba" version="1.1" viewbox="0 0 16 16" x="0px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px"><g><rect height="2" width="16" y="1"></rect><rect height="2" width="16" y="7"></rect><rect height="2" width="16" y="13"></rect>
#  </g></svg>
#  </a>,
#  <a class="u-button-style u-nav-link u-text-active-palette-1-base u-text-hover-palette-2-base" href="Home.html" style="padding: 10px 20px;">Home</a>,
#  <a class="u-button-style u-nav-link u-text-active-palette-1-base u-text-hover-palette-2-base" href="Structure.html" style="padding: 10px 20px;">Structure</a>,
#  <a class="u-button-style u-nav-link u-text-active-palette-1-base u-text-hover-palette-2-base" href="Courses.html" style="padding: 10px 20px;">Courses</a>,
#  <a class="u-button-style u-nav-link u-text-active-palette-1-base u-text-hover-palette-2-base" href="Application.html" style="padding: 10px 20px;">Application</a>,
#  <a class="u-button-style u-nav-link u-text-active-palette-1-base u-text-hover-palette-2-base" href="Testimonials.html" style="padding: 10px 20px;">Testimonials</a>,
#  <a class="u-button-style u-nav-link u-text-active-palette-1-base u-text-hover-palette-2-base" href="Facilities.html" style="padding: 10px 20px;">Facilities</a>,
#  <a class="u-button-style u-nav-link u-text-active-palette-1-base u-text-hover-palette-2-base" href="FAQ.html" style="padding: 10px 20px;">FAQ</a>,
#  <a class="u-button-style u-nav-link u-text-active-palette-1-base u-text-hover-palette-2-base" href="Media.html" style="padding: 10px 20px;">Media</a>,
#  <a class="u-button-style u-nav-link u-text-active-palette-1-base u-text-hover-palette-2-base" href="Contact.html" style="padding: 10px 20px;">Contact</a>,
#  <a class="u-button-style u-nav-link" href="Home.html">Home</a>,
#  <a class="u-button-style u-nav-link" href="Structure.html">Structure</a>,
#  <a class="u-button-style u-nav-link" href="Courses.html">Courses</a>,
#  <a class="u-button-style u-nav-link" href="Application.html">Application</a>,
#  <a class="u-button-style u-nav-link" href="Testimonials.html">Testimonials</a>,
#  <a class="u-button-style u-nav-link" href="Facilities.html">Facilities</a>,
#  <a class="u-button-style u-nav-link" href="FAQ.html">FAQ</a>,
#  <a class="u-button-style u-nav-link" href="Media.html">Media</a>,
#  <a class="u-button-style u-nav-link" href="Contact.html">Contact</a>,
#  <a class="u-carousel-control u-carousel-control-prev u-hidden u-icon-rectangle u-text-custom-color-2 u-block-6983-5" data-u-slide="prev" href="#carousel-d1a1" role="button">
#  <span aria-hidden="true">
#  <svg class="u-svg-link" viewbox="0 0 477.175 477.175"><path d="M145.188,238.575l215.5-215.5c5.3-5.3,5.3-13.8,0-19.1s-13.8-5.3-19.1,0l-225.1,225.1c-5.3,5.3-5.3,13.8,0,19.1l225.1,225
#                      c2.6,2.6,6.1,4,9.5,4s6.9-1.3,9.5-4c5.3-5.3,5.3-13.8,0-19.1L145.188,238.575z"></path></svg>
#  </span>
#  <span class="sr-only">Previous</span>
#  </a>,
#  <a class="u-absolute-vcenter u-carousel-control u-carousel-control-next u-hidden u-icon-rectangle u-text-custom-color-2 u-block-6983-4" data-u-slide="next" href="#carousel-d1a1" role="button">
#  <span aria-hidden="true">
#  <svg class="u-svg-link" viewbox="0 0 477.175 477.175"><path d="M360.731,229.075l-225.1-225.1c-5.3-5.3-13.8-5.3-19.1,0s-5.3,13.8,0,19.1l215.5,215.5l-215.5,215.5
#                      c-5.3,5.3-5.3,13.8,0,19.1c2.6,2.6,6.1,4,9.5,4c3.4,0,6.9-1.3,9.5-4l225.1-225.1C365.931,242.875,365.931,234.275,360.731,229.075z"></path></svg>
#  </span>
#  <span class="sr-only">Next</span>
#  </a>,
#  <a class="u-btn u-btn-round u-button-style u-file-link u-radius-50 u-btn-1" href="files/SWS2024_290224.pdf" target="_blank">Click to view promotional slides</a>,
#  <a class="u-absolute-vcenter u-carousel-control u-carousel-control-prev u-grey-70 u-icon-circle u-opacity u-opacity-70 u-spacing-10 u-text-white u-carousel-control-1" data-u-slide="prev" href="#carousel-88f0" role="button">
#  <span aria-hidden="true">
#  <svg viewbox="0 0 451.847 451.847"><path d="M97.141,225.92c0-8.095,3.091-16.192,9.259-22.366L300.689,9.27c12.359-12.359,32.397-12.359,44.751,0
#  c12.354,12.354,12.354,32.388,0,44.748L173.525,225.92l171.903,171.909c12.354,12.354,12.354,32.391,0,44.744
#  c-12.354,12.365-32.386,12.365-44.745,0l-194.29-194.281C100.226,242.115,97.141,234.018,97.141,225.92z"></path></svg>
#  </span>
#  <span class="sr-only">
#  <svg viewbox="0 0 451.847 451.847"><path d="M97.141,225.92c0-8.095,3.091-16.192,9.259-22.366L300.689,9.27c12.359-12.359,32.397-12.359,44.751,0
#  c12.354,12.354,12.354,32.388,0,44.748L173.525,225.92l171.903,171.909c12.354,12.354,12.354,32.391,0,44.744
#  c-12.354,12.365-32.386,12.365-44.745,0l-194.29-194.281C100.226,242.115,97.141,234.018,97.141,225.92z"></path></svg>
#  </span>
#  </a>,
#  <a class="u-absolute-vcenter u-carousel-control u-carousel-control-next u-grey-70 u-icon-circle u-opacity u-opacity-70 u-spacing-10 u-text-white u-carousel-control-2" data-u-slide="next" href="#carousel-88f0" role="button">
#  <span aria-hidden="true">
#  <svg viewbox="0 0 451.846 451.847"><path d="M345.441,248.292L151.154,442.573c-12.359,12.365-32.397,12.365-44.75,0c-12.354-12.354-12.354-32.391,0-44.744
#  L278.318,225.92L106.409,54.017c-12.354-12.359-12.354-32.394,0-44.748c12.354-12.359,32.391-12.359,44.75,0l194.287,194.284
#  c6.177,6.18,9.262,14.271,9.262,22.366C354.708,234.018,351.617,242.115,345.441,248.292z"></path></svg>
#  </span>
#  <span class="sr-only">
#  <svg viewbox="0 0 451.846 451.847"><path d="M345.441,248.292L151.154,442.573c-12.359,12.365-32.397,12.365-44.75,0c-12.354-12.354-12.354-32.391,0-44.744
#  L278.318,225.92L106.409,54.017c-12.354-12.359-12.354-32.394,0-44.748c12.354-12.359,32.391-12.359,44.75,0l194.287,194.284
#  c6.177,6.18,9.262,14.271,9.262,22.366C354.708,234.018,351.617,242.115,345.441,248.292z"></path></svg>
#  </span>
#  </a>,
#  <a class="u-btn u-btn-round u-button-style u-file-link u-radius u-btn-1" href="files/SWS2024ProgramSchedule.pdf" target="_blank">Click to download Programme Schedule</a>,
#  <a class="u-active-none u-border-none u-btn u-button-link u-button-style u-hover-none u-none u-text-palette-1-base u-btn-1" href="https://nicepage.com/c/real-estate-website-templates">sws.comp.nus.edu.sg</a>]

# %%
#get href attribute of all links
links_href = []
for link in links:
    href = link.get('href')
    if not href.startswith("http"):
        href = STARTING_URL + href
        links_href.append(href)        

def filter_link(link):
    return link.endswith('htm') or link.endswith('html')

links_href = list(filter(filter_link, links_href))
links_href = list(set(links_href))
links_href
# Out:
# ['https://sws.comp.nus.edu.sg/Home.html',
#  'https://sws.comp.nus.edu.sg/Contact.html',
#  'https://sws.comp.nus.edu.sg/Media.html',
#  'https://sws.comp.nus.edu.sg/Testimonials.html',
#  'https://sws.comp.nus.edu.sg/Structure.html',
#  'https://sws.comp.nus.edu.sg/Application.html',
#  'https://sws.comp.nus.edu.sg/FAQ.html',
#  'https://sws.comp.nus.edu.sg/Courses.html',
#  'https://sws.comp.nus.edu.sg/Facilities.html']

# %%
for url in links_href:
    time.sleep(0.1)
    page = requests.get(url)
    html = page.content
    htmls.append(html)
    soup = BeautifulSoup(page.content, 'html.parser')
    text = soup.text.strip()
    urls.append(url)
    texts.append(text)
    
result = DataFrame({'url': urls, 'text': texts, 'html': htmls})
result
# Out:
#                                              url  \
# 0                   https://sws.comp.nus.edu.sg/
# 1          https://sws.comp.nus.edu.sg/Home.html
# 2       https://sws.comp.nus.edu.sg/Contact.html
# 3         https://sws.comp.nus.edu.sg/Media.html
# 4  https://sws.comp.nus.edu.sg/Testimonials.html
# 5     https://sws.comp.nus.edu.sg/Structure.html
# 6   https://sws.comp.nus.edu.sg/Application.html
# 7           https://sws.comp.nus.edu.sg/FAQ.html
# 8       https://sws.comp.nus.edu.sg/Courses.html
# 9    https://sws.comp.nus.edu.sg/Facilities.html
#
#                                                 text  \
# 0  Home\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 1  Home\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 2  Contact\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 3  Media\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 4  Testimonials\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 5  Structure\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 6  Application\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 7  FAQ\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 8  Courses\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 9  Facilities\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
#
#                                                 html
# 0  b'<!DOCTYPE html>\n<html style="font-size: 16p...
# 1  b'<!DOCTYPE html>\n<html style="font-size: 16p...
# 2  b'<!DOCTYPE html>\n<html style="font-size: 16p...
# 3  b'<!DOCTYPE html>\n<html style="font-size: 16p...
# 4  b'<!DOCTYPE html>\n<html style="font-size: 16p...
# 5  b'<!DOCTYPE html>\n<html style="font-size: 16p...
# 6  b'<!DOCTYPE html>\n<html style="font-size: 16p...
# 7  b'<!DOCTYPE html>\n<html style="font-size: 16p...
# 8  b'<!DOCTYPE html>\n<html style="font-size: 16p...
# 9  b'<!DOCTYPE html>\n<html style="font-size: 16p...
